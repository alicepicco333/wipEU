# %%
import openpyxl
import csv 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import ttest_ind
#pulzia dati e creazione file csv
def column_remove(dataframe):
    dataframe = dataframe.iloc[:, :7]
    return dataframe
#education science and research
df_total_research_fundings = pd.read_excel("../data/education_science_research/total_research_funding.xlsx", skiprows=18)
df_men_research_fundings = pd.read_excel("../data/education_science_research/men_research_funding.xlsx", skiprows=18)
df_women_research_fundings = pd.read_excel("../data/education_science_research/women_research_funding.xlsx", skiprows=18)
df_total_research_fundings.to_csv("../data/education_science_research/total_research_funding.csv", index=False)
df_men_research_fundings.to_csv("../data/education_science_research/men_research_funding.csv", index=False)
df_women_research_fundings.to_csv("../data/education_science_research/women_research_funding.csv", index=False)
df_total_research_fundings = df_total_research_fundings
df_men_research_fundings = df_men_research_fundings
df_women_research_fundings = df_women_research_fundings

#environment and climate change
df_total_political_executives = pd.read_excel("../data/environment_climate_change/total_political_executives_climate.xlsx", skiprows=18)
df_men_political_executives = pd.read_excel("../data/environment_climate_change/men_political_executives_climate.xlsx", skiprows=18)
df_women_political_executives = pd.read_excel("../data/environment_climate_change/women_political_executives_climate.xlsx", skiprows=18)
df_total_political_executives.to_csv("../data/environment_climate_change/total_political_executives_climate.csv", index=False)
df_men_political_executives.to_csv("../data/environment_climate_change/men_political_executives_climate.csv", index=False)
df_women_political_executives.to_csv("../data/environment_climate_change/women_political_executives_climate.csv", index=False)
df_total_political_executives = df_total_political_executives
df_men_political_executives = df_men_political_executives
df_women_political_executives = df_women_political_executives

#major political party leaders
df_total_political_parties = pd.read_excel("../data/major_political_party_leaders/total_political_parties.xlsx", skiprows=18)
df_men_political_parties = pd.read_excel("../data/major_political_party_leaders/men_political_parties.xlsx", skiprows=18)
df_women_political_parties = pd.read_excel("../data/major_political_party_leaders/women_political_parties.xlsx", skiprows=18)
df_total_political_parties.to_csv("../data/major_political_party_leaders/total_political_parties.csv", index=False)
df_men_political_parties.to_csv("../data/major_political_party_leaders/men_political_parties.csv", index=False)
df_women_political_parties.to_csv("../data/major_political_party_leaders/women_political_parties.csv", index=False)
df_total_political_parties = df_total_political_parties
df_men_political_parties = df_men_political_parties
df_women_political_parties = df_women_political_parties



#public EU administrations
df_public_adm_total = pd.read_excel("../data/European_public_admin/european_agencies_total.xlsx", skiprows=18)
df_public_adm_men = pd.read_excel("../data/European_public_admin/european_agencies_men.xlsx", skiprows=18)
df_public_adm_women = pd.read_excel("../data/European_public_admin/european_agencies_women.xlsx", skiprows=18)
df_public_adm_total.to_csv("../data/European_public_admin/european_agencies_total.csv", index=False)
df_public_adm_men.to_csv("../data/European_public_admin/european_agencies_men.csv", index=False)
df_public_adm_women.to_csv("../data/European_public_admin/european_agencies_women.csv", index=False)
df_public_adm_total = df_public_adm_total
df_public_adm_men = df_public_adm_men
df_public_adm_women = df_public_adm_men

#european courts
df_total_european_court = pd.read_excel("../data/european_courts/total_judges_european_court.xlsx", skiprows=18)
df_men_european_court = pd.read_excel("../data/european_courts/men_judges_european_court.xlsx", skiprows=18)
df_women_european_court = pd.read_excel("../data/european_courts/women_judges_european_court.xlsx", skiprows=18)
df_total_european_court.to_csv("../data/european_courts/total_judges_european_court.csv", index=False)
df_men_european_court.to_csv("../data/european_courts/men_judges_european_court.csv", index=False)
df_women_european_court.to_csv("../data/european_courts/women_judges_european_court.csv", index=False)
df_total_european_court = df_total_european_court
df_men_european_court = df_men_european_court
df_women_european_court = df_women_european_court

#european finance
df_european_financial_institutions_total = pd.read_excel("../data/European_finance/european_financial_institutions_total.xlsx", skiprows=18)
df_european_financial_institutions_men = pd.read_excel("../data/European_finance/european_financial_institutions_men.xlsx", skiprows=18)
df_european_financial_institutions_women = pd.read_excel("../data/European_finance/european_financial_institutions_women.xlsx", skiprows=18)
df_european_financial_institutions_total.to_csv("../data/European_finance/european_financial_institutions_total.csv", index = False)
df_european_financial_institutions_men.to_csv("../data/European_finance/european_financial_institutions_men.csv", index= False)
df_european_financial_institutions_women.to_csv("../data/European_finance/european_financial_institutions_women.csv", index= False)
df_european_financial_institutions_total = df_european_financial_institutions_total
df_european_financial_institutions_men = df_european_financial_institutions_men
df_european_financial_institutions_women = df_european_financial_institutions_women

# %%
df_women_research_fundings = df_women_research_fundings.rename(columns={"Geographic region\Time": "Geographic region"})
df_women_research_fundings = column_remove(df_women_research_fundings)

# df_women_research_fundings.head()
#numero di donne che ricoprono ruoli fondamentali in associazioni di fondi

# %%
df_public_adm_women = df_public_adm_women.rename(columns={"Time": "Agency"})
df_public_adm_women.head()
df_public_adm_women = df_public_adm_women.drop([0, 1])
df_public_adm_women=column_remove(df_public_adm_women)
# df_public_adm_women.head()
#numero totale di donne che ricoprono ruoli fondamentali in pubblica amministrazione EU

# %%
# Summary Statistics
summary_stats_admin = df_public_adm_women.describe()
summary_stats_funding = df_women_research_fundings.describe()
print(summary_stats_admin)
print(summary_stats_funding)
# Out:
#                                                    Agency  2023  2022  2021  \
# count                                                  45    39    38    38
# unique                                                 45    23    23    21
# top     Agency for the Cooperation of Energy Regulator...    17    18    18
# freq                                                    1     5     5     4
#
#         2020  2019  2018
# count     38    37    37
# unique    22    20    22
# top       21    20    24
# freq       4     4     4
#              2023        2022        2021        2020        2019        2018
# count   42.000000   42.000000   42.000000   42.000000   42.000000   42.000000
# mean    32.166667   29.547619   28.571429   27.500000   27.023810   26.309524
# std     81.450544   76.934309   74.407298   71.935015   70.247468   68.065782
# min      1.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
print(df_public_adm_women.head())
print(df_women_research_fundings.head())
# Out:
#                                               Agency 2023 2022 2021 2020 2019  \
# 2  Agency for the Cooperation of Energy Regulator...   19   20   20   20   20
# 3  Body of European Regulators for Electronic Com...   19   18   19   21   22
# 4              Community Plant Variety Office (CPVO)   17   16   15   16   17
# 5                        Euratom Supply Agency (ESA)  NaN  NaN  NaN  NaN  NaN
# 6           European Agency for Reconstruction (EAR)  NaN  NaN  NaN  NaN  NaN
#
#   2018
# 2   21
# 3   24
# 4   16
# 5  NaN
# 6  NaN
#         Geographic region  2023  2022  2021  2020  2019  2018
# 0                 Albania     5     5     4     4     4     4
# 1                 Austria    18    19    18    13    12    12
# 2  Bosnia and Herzegovina     4     4     4     3     3     3
# 3                 Belgium     4     5     5     6     6     7
# 4                Bulgaria     6     6     5     5     4     4

# %%
# Summary Statistics
summary_stats_admin = df_public_adm_women.describe()
summary_stats_funding = df_women_research_fundings.describe()
print("Summary Statistics for Public Administration Data:\n", summary_stats_admin)
print("Summary Statistics for Research Funding Data:\n", summary_stats_funding)
# Out:
# Summary Statistics for Public Administration Data:
#                                                     Agency  2023  2022  2021  \
# count                                                  45    39    38    38
# unique                                                 45    23    23    21
# top     Agency for the Cooperation of Energy Regulator...    17    18    18
# freq                                                    1     5     5     4
#
#         2020  2019  2018
# count     38    37    37
# unique    22    20    22
# top       21    20    24
# freq       4     4     4
# Summary Statistics for Research Funding Data:
#               2023        2022        2021        2020        2019        2018
# count   42.000000   42.000000   42.000000   42.000000   42.000000   42.000000
# mean    32.166667   29.547619   28.571429   27.500000   27.023810   26.309524
# std     81.450544   76.934309   74.407298   71.935015   70.247468   68.065782
# ...

# %%
# print(df_women_research_fundings.columns)
# print(df_women_research_fundings.head())

# %%
# Year-wise Comparison
yearly_comparison = df_women_research_fundings.set_index('Geographic region').transpose().join(df_public_adm_women.set_index('Agency').transpose())
print("Yearly Comparison:\n", yearly_comparison)

# Regional Comparison
regional_comparison = pd.merge(df_women_research_fundings, df_public_adm_women, how='inner', left_on='Geographic region', right_on='Agency')
print("Regional Comparison:\n", regional_comparison)

# Correlation Coefficient
correlation_coefficient = df_women_research_fundings.iloc[:, 1:].corrwith(df_public_adm_women.iloc[:, 1:])
print("Correlation Coefficient:\n", correlation_coefficient)
# Out:
# Yearly Comparison:
#        Albania  Austria  Bosnia and Herzegovina  Belgium  Bulgaria  Cyprus  \
# 2023        5       18                       4        4         6       2
# 2022        5       19                       4        5         6       2
# 2021        4       18                       4        5         5       2
# 2020        4       13                       3        6         5       2
# 2019        4       12                       3        6         4       3
# 2018        4       12                       3        7         4       3
#
#       Czechia  Germany  Denmark  Estonia  ...  \
# 2023        3       51       13        3  ...
# 2022        3       51       13        2  ...
# 2021        3       55       12        1  ...
# 2020        2       50       12        1  ...
# 2019        2       49       11        1  ...
# 2018        3       39       10        1  ...
#
#       European Union Agency for Fundamental Rights (FRA)  \
# ...

# %%
cols = ['2023', '2022', '2021', '2020', '2019', '2018']
df_public_adm_women[cols] = df_public_adm_women[cols].apply(pd.to_numeric, errors='coerce')

# %%
# # Check data types
# print(df_women_research_fundings.dtypes)
# print(df_public_adm_women.dtypes)

# # Check for missing values
# print(df_women_research_fundings.isnull().sum())
# print(df_public_adm_women.isnull().sum())

# %%
df_women_research_fundings = df_women_research_fundings.dropna()
df_public_adm_women = df_public_adm_women.dropna()
df_women_research_fundings = df_women_research_fundings.reset_index(drop=True)
df_public_adm_women = df_public_adm_women.reset_index(drop=True)

# %%
min_length = min(len(df_women_research_fundings), len(df_public_adm_women))
df_women_research_fundings = df_women_research_fundings.iloc[:min_length]
df_public_adm_women = df_public_adm_women.iloc[:min_length]
# Regression Modeling
X = sm.add_constant(df_women_research_fundings.iloc[:, 2:])
model = sm.OLS(df_public_adm_women['2023'], X)
results = model.fit()
print("Regression Results:\n", results.summary())



# Hypothesis Testing (e.g., t-test)
t_stat, p_value = ttest_ind(df_women_research_fundings['2023'], df_public_adm_women['2023'], equal_var=False)
print(f'T-statistic: {t_stat}, p-value: {p_value}')
# Out:
# Regression Results:
#                              OLS Regression Results
# ...
# Dep. Variable:                   2023   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                 -0.078
# Method:                 Least Squares   F-statistic:                    0.5064
# Date:                Tue, 23 Jan 2024   Prob (F-statistic):              0.769
# Time:                        16:49:53   Log-Likelihood:                -131.02
# No. Observations:                  35   AIC:                             274.0
# Df Residuals:                      29   BIC:                             283.4
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.2781      2.118     10.049      0.000      16.947      25.609
# ...

# %%
# Time Series Plots
# Time Series Plots
ax1 = df_women_research_fundings.set_index('Geographic region').transpose().plot(
    title='Number of Women in Public Administration Over Time', figsize=(16, 10))
plt.xticks(rotation=45)
ax1.invert_xaxis()  # Reverse the x-axis
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

ax2 = df_public_adm_women.set_index('Agency').transpose().plot(
    title='Number of Women in Funding Institutes Over Time', figsize=(16, 10))
plt.xticks(rotation=45)
ax2.invert_xaxis()  # Reverse the x-axis
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


# # Scatter Plots
# scatter_plot = df_women_research_fundings.plot.scatter(
#     x='2023', y='2023', title='Scatter Plot: Women in Admin vs Funding', figsize=(10, 6))
# plt.show()

# %% [markdown]
# Summary Statistics for Public Administration Data: This provides a summary of the df_public_adm_women dataframe, which contains data on women in key decision-making positions in public administration across various European agencies. The ‘count’ row shows the number of non-missing observations for each year. For example, there are 45 agencies in the dataset, and data for 39 of them is available for the year 2023. The ‘unique’ row shows the number of distinct values in each year, indicating the range of representation of women across agencies. The ‘top’ row shows the most common number of women in key positions in a given year, and ‘freq’ shows the frequency of this most common value.
#
# Summary Statistics for Research Funding Data: This provides a summary of the df_women_research_fundings dataframe, which contains data on women in key decision-making positions in research funding organizations. The ‘count’ row shows the number of non-missing observations for each year. The ‘mean’ row shows the average number of women in key positions for each year, the ‘std’ row shows the standard deviation, indicating the variability in the number of women across different organizations. The ‘min’ and ‘max’ rows show the minimum and maximum number of women in key positions, respectively, and the ‘25%’, ‘50%’, and ‘75%’ rows show the 25th percentile (1st quartile), median (2nd quartile), and 75th percentile (3rd quartile), respectively, indicating the distribution of women in key positions.
#
# Yearly Comparison: This shows the number of women in key decision-making positions in public administration and research funding for each agency and country over the years. Each row represents a year, and each column represents an agency or a country. The values in the table represent the number of women in key positions.
#
# OLS Regression Results: This provides the results of an Ordinary Least Squares (OLS) regression analysis, which is used to understand the relationship between the number of women in key positions in the year 2023 (dependent variable) and the number in previous years (independent variables). The coefficients (‘coef’) represent the change in the number of women in key positions in 2023 associated with a one-unit change in the number in the corresponding year, assuming all other years are held constant. The p-values (‘P>|t|’) are used to test the null hypothesis that each coefficient is equal to zero. A p-value less than 0.05 typically indicates that the coefficient is statistically significant. However, in this case, none of the p-values are less than 0.05, suggesting that the number of women in key positions in previous years does not significantly predict the number in 2023. The R-squared value is 0.080, indicating that the model explains only 8% of the variance in the number of women in key positions in 2023, suggesting that the model does not fit the data very well.
#
#
# Time Series Plots (first two): These plots show the number of women in public administration and research funding over time. The x-axis represents time (years from 2018 to 2023), and the y-axis represents the number of women. Each line in the plot corresponds to a different geographic region or agency. These plots can help you understand trends and patterns in the number of women in public administration and research funding over time.

# %%
print(df_public_adm_total.head())
print(df_total_research_fundings.head())
# Out:
#                                                 Time   2023   2022   2021  \
# 0                                         Entity\Sex  Total  Total  Total
# 1                                              Total   1325   1287   1288
# 2  Agency for the Cooperation of Energy Regulator...     27     27     27
# 3  Body of European Regulators for Electronic Com...     26     27     27
# 4              Community Plant Variety Office (CPVO)     27     28     28
#
#     2020   2019   2018   2017   2016   2015  ...   2012   2011   2010   2009  \
# 0  Total  Total  Total  Total  Total  Total  ...  Total  Total  Total  Total
# 1   1289   1274   1288   1273   1289   1264  ...   1237    927    879    827
# 2     26     28     28     27     28     27  ...     27     26    NaN    NaN
# 3     27     27     28     28     28     28  ...     26    NaN    NaN    NaN
# 4     28     28     29     29     29     29  ...     27     28     28     28
#
#     2008   2007   2006   2005   2004   2003
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # Import seaborn for advanced plotting options

# Prepare data for boxplot
public_adm_data = df_public_adm_women.drop(columns=['Agency']).T
research_funding_data = df_women_research_fundings.drop(columns=['Geographic region']).T

# Create subplots with increased figure size
fig, axs = plt.subplots(2, figsize=(10, 8))

# Enhance style with seaborn
sns.set_style("whitegrid")

# Create boxplot for public administration data with added colors and vertical orientation
sns.boxplot(data=public_adm_data, orient='v', palette="Set2", ax=axs[0])
axs[0].set_title('Public Administration')
axs[0].set_ylabel('Number of Women in Influential Roles')
axs[0].set_xlabel('Year')

# Create boxplot for research funding data with added colors and vertical orientation
sns.boxplot(data=research_funding_data, orient='v', palette="Set2", ax=axs[1])
axs[1].set_title('Research Funding')
axs[1].set_ylabel('Number of Women in Influential Roles')
axs[1].set_xlabel('Year')

# Adjust layout to prevent overlap and ensure readability 
plt.tight_layout()
plt.show()

# %% [markdown]
# Each box in the plot represents a region or agency. The line in the middle of the box indicates the median number of women in influential roles in that region or agency. The box’s length shows the interquartile range, which represents the middle 50% of the data. The whiskers extend to the minimum and maximum data points that are not considered outliers, and any points outside the whiskers are considered outliers.
#
# In the context of your data:
#
# Public Administration: The boxplot for “df_public_adm_women” shows the distribution of women in influential roles across different European agencies. The variation in the box sizes and positions indicates that the representation of women in these roles varies significantly across different agencies.
#
# Research Funding: The boxplot for “df_women_research_fundings” shows the distribution of women in key decision-making positions within research funding organisations across different regions or agencies. The smaller boxes and lower position suggest that the representation of women in these roles is generally low.
